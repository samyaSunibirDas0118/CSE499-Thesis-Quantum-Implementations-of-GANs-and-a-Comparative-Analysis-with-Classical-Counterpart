# %%
# !pip install pennylane
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pennylane
#   Downloading PennyLane-0.27.0-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 36.2 MB/s
# Requirement already satisfied: appdirs in /usr/local/lib/python3.8/dist-packages (from pennylane) (1.4.4)
# Collecting semantic-version>=2.7
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (from pennylane) (2.8.8)
# Collecting pennylane-lightning>=0.27
#   Downloading PennyLane_Lightning-0.27.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.3 MB)
#      |████████████████████████████████| 15.3 MB 60.9 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from pennylane) (1.21.6)
# Collecting autoray>=0.3.1
#   Downloading autoray-0.5.3-py3-none-any.whl (39 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from pennylane) (2.23.0)
# Requirement already satisfied: autograd in /usr/local/lib/python3.8/dist-packages (from pennylane) (1.5)
# Requirement already satisfied: toml in /usr/local/lib/python3.8/dist-packages (from pennylane) (0.10.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from pennylane) (1.7.3)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.8/dist-packages (from pennylane) (5.2.0)
# Collecting retworkx
#   Downloading retworkx-0.12.1-py3-none-any.whl (10 kB)
# Collecting ninja
#   Downloading ninja-1.11.1-py2.py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (145 kB)
#      |████████████████████████████████| 145 kB 75.0 MB/s
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.8/dist-packages (from autograd->pennylane) (0.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->pennylane) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->pennylane) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->pennylane) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->pennylane) (1.24.3)
# Collecting rustworkx==0.12.1
#   Downloading rustworkx-0.12.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 49.2 MB/s
# Installing collected packages: rustworkx, ninja, semantic-version, retworkx, pennylane-lightning, autoray, pennylane
# Successfully installed autoray-0.5.3 ninja-1.11.1 pennylane-0.27.0 pennylane-lightning-0.27.0 retworkx-0.12.1 rustworkx-0.12.1 semantic-version-2.10.0

# %%
# Library imports
import math
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pennylane as qml

# Pytorch imports
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader

# Set the random seed for reproducibility
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

# %%
class DigitsDataset(Dataset):
    """Pytorch dataloader for the Optical Recognition of Handwritten Digits Data Set"""

    def __init__(self, csv_file, label=0, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.csv_file = csv_file
        self.transform = transform
        self.df = self.filter_by_label(label)

    def filter_by_label(self, label):
        # Use pandas to return a dataframe of only zeros
        df = pd.read_csv(self.csv_file)
        df = df.loc[df.iloc[:, -1] == label]
        return df

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        image = self.df.iloc[idx, :-1] / 16
        image = np.array(image)
        image = image.astype(np.float32).reshape(8, 8)

        if self.transform:
            image = self.transform(image)

        # Return image and label
        return image, 0

# %%
image_size = 8  # Height / width of the square images
batch_size = 1

transform = transforms.Compose([transforms.ToTensor()])
dataset = DigitsDataset(csv_file="/tmp/optdigits.tra", transform=transform)
dataloader = torch.utils.data.DataLoader(
    dataset, batch_size=batch_size, shuffle=True, drop_last=True
)

# %%
plt.figure(figsize=(8,2))

for i in range(8):
    image = dataset[i][0].reshape(image_size,image_size)
    plt.subplot(1,8,i+1)
    plt.axis('off')
    plt.imshow(image.numpy(), cmap='gray')

plt.show()

# %%
class Discriminator(nn.Module):
    """Fully connected classical discriminator"""

    def __init__(self):
        super().__init__()

        self.model = nn.Sequential(
            # Inputs to first hidden layer (num_input_features -> 64)
            nn.Linear(image_size * image_size, 64),
            nn.ReLU(),
            # First hidden layer (64 -> 16)
            nn.Linear(64, 16),
            nn.ReLU(),
            # Second hidden layer (16 -> output)
            nn.Linear(16, 1),
            nn.Sigmoid(),
        )

    def forward(self, x):
        return self.model(x)

# %%
# Quantum variables
n_qubits = 5  # Total number of qubits / N
n_a_qubits = 1  # Number of ancillary qubits / N_A
q_depth = 6  # Depth of the parameterised quantum circuit / D
n_generators = 4  # Number of subgenerators for the patch method / N_G

# %%
# Quantum simulator
dev = qml.device("lightning.qubit", wires=n_qubits)
# Enable CUDA device if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
@qml.qnode(dev, interface="torch", diff_method="parameter-shift")
def quantum_circuit(noise, weights):

    weights = weights.reshape(q_depth, n_qubits)

    # Initialise latent vectors
    for i in range(n_qubits):
        qml.RY(noise[i], wires=i)

    # Repeated layer
    for i in range(q_depth):
        # Parameterised layer
        for y in range(n_qubits):
            qml.RY(weights[i][y], wires=y)

        # Control Z gates
        for y in range(n_qubits - 1):
            qml.CZ(wires=[y, y + 1])

    return qml.probs(wires=list(range(n_qubits)))


# For further info on how the non-linear transform is implemented in Pennylane
# https://discuss.pennylane.ai/t/ancillary-subsystem-measurement-then-trace-out/1532
def partial_measure(noise, weights):
    # Non-linear Transform
    probs = quantum_circuit(noise, weights)
    probsgiven0 = probs[: (2 ** (n_qubits - n_a_qubits))]
    probsgiven0 /= torch.sum(probs)

    # Post-Processing
    probsgiven = probsgiven0 / torch.max(probsgiven0)
    return probsgiven

# %%
class PatchQuantumGenerator(nn.Module):
    """Quantum generator class for the patch method"""

    def __init__(self, n_generators, q_delta=1):
        """
        Args:
            n_generators (int): Number of sub-generators to be used in the patch method.
            q_delta (float, optional): Spread of the random distribution for parameter initialisation.
        """

        super().__init__()

        self.q_params = nn.ParameterList(
            [
                nn.Parameter(q_delta * torch.rand(q_depth * n_qubits), requires_grad=True)
                for _ in range(n_generators)
            ]
        )
        self.n_generators = n_generators

    def forward(self, x):
        # Size of each sub-generator output
        patch_size = 2 ** (n_qubits - n_a_qubits)

        # Create a Tensor to 'catch' a batch of images from the for loop. x.size(0) is the batch size.
        images = torch.Tensor(x.size(0), 0).to(device)

        # Iterate over all sub-generators
        for params in self.q_params:

            # Create a Tensor to 'catch' a batch of the patches from a single sub-generator
            patches = torch.Tensor(0, patch_size).to(device)
            for elem in x:
                q_out = partial_measure(elem, params).float().unsqueeze(0)
                patches = torch.cat((patches, q_out))

            # Each batch of patches is concatenated with each other to create a batch of images
            images = torch.cat((images, patches), 1)

        return images

# %%
lrG = 0.3  # Learning rate for the generator
lrD = 0.01  # Learning rate for the discriminator
num_iter = 2000  # Number of training iterations

# %%
discriminator = Discriminator().to(device)
generator = PatchQuantumGenerator(n_generators).to(device)

# Binary cross entropy
criterion = nn.BCELoss()

# Optimisers
optD = optim.SGD(discriminator.parameters(), lr=lrD)
optG = optim.SGD(generator.parameters(), lr=lrG)

real_labels = torch.full((batch_size,), 1.0, dtype=torch.float, device=device)
fake_labels = torch.full((batch_size,), 0.0, dtype=torch.float, device=device)

# Fixed noise allows us to visually track the generated images throughout training
fixed_noise = torch.rand(8, n_qubits, device=device) * math.pi / 2

# Iteration counter
counter = 0

# Collect images for plotting later
results = []

while True:
    for i, (data, _) in enumerate(dataloader):

        # Data for training the discriminator
        data = data.reshape(-1, image_size * image_size)
        real_data = data.to(device)

        # Noise follwing a uniform distribution in range [0,pi/2)
        noise = torch.rand(batch_size, n_qubits, device=device) * math.pi / 2
        fake_data = generator(noise)

        # Training the discriminator
        discriminator.zero_grad()
        outD_real = discriminator(real_data).view(-1)
        outD_fake = discriminator(fake_data.detach()).view(-1)

        errD_real = criterion(outD_real, real_labels)
        errD_fake = criterion(outD_fake, fake_labels)
        # Propagate gradients
        errD_real.backward()
        errD_fake.backward()

        errD = errD_real + errD_fake
        optD.step()

        # Training the generator
        generator.zero_grad()
        outD_fake = discriminator(fake_data).view(-1)
        errG = criterion(outD_fake, real_labels)
        errG.backward()
        optG.step()

        counter += 1

        # Show loss values
        if counter % 10 == 0:
            print(f'Iteration: {counter}, Discriminator Loss: {errD:0.3f}, Generator Loss: {errG:0.3f}')
            test_images = generator(fixed_noise).view(8,1,image_size,image_size).cpu().detach()

            # Save images every 50 iterations
            if counter % 50 == 0:
                results.append(test_images)

        if counter == num_iter:
            break
    if counter == num_iter:
        break
# Out:
# Iteration: 10, Discriminator Loss: 1.349, Generator Loss: 0.648
# Iteration: 20, Discriminator Loss: 1.321, Generator Loss: 0.665
# Iteration: 30, Discriminator Loss: 1.322, Generator Loss: 0.662
# Iteration: 40, Discriminator Loss: 1.301, Generator Loss: 0.670
# Iteration: 50, Discriminator Loss: 1.334, Generator Loss: 0.670
# Iteration: 60, Discriminator Loss: 1.281, Generator Loss: 0.691
# Iteration: 70, Discriminator Loss: 1.245, Generator Loss: 0.710
# Iteration: 80, Discriminator Loss: 1.233, Generator Loss: 0.714
# Iteration: 90, Discriminator Loss: 1.216, Generator Loss: 0.718
# Iteration: 100, Discriminator Loss: 1.215, Generator Loss: 0.700
# Iteration: 110, Discriminator Loss: 1.220, Generator Loss: 0.733
# Iteration: 120, Discriminator Loss: 1.195, Generator Loss: 0.730
# Iteration: 130, Discriminator Loss: 1.216, Generator Loss: 0.697
# Iteration: 140, Discriminator Loss: 1.258, Generator Loss: 0.647
# Iteration: 150, Discriminator Loss: 1.283, Generator Loss: 0.628
# Iteration: 160, Discriminator Loss: 1.301, Generator Loss: 0.630
# Iteration: 170, Discriminator Loss: 1.244, Generator Loss: 0.647
# Iteration: 180, Discriminator Loss: 1.179, Generator Loss: 0.701
# Iteration: 190, Discriminator Loss: 1.207, Generator Loss: 0.694
# Iteration: 200, Discriminator Loss: 1.199, Generator Loss: 0.728
# Iteration: 210, Discriminator Loss: 1.305, Generator Loss: 0.640
# Iteration: 220, Discriminator Loss: 1.286, Generator Loss: 0.632
# Iteration: 230, Discriminator Loss: 1.255, Generator Loss: 0.667
# Iteration: 240, Discriminator Loss: 1.342, Generator Loss: 0.617
# Iteration: 250, Discriminator Loss: 1.237, Generator Loss: 0.680
# Iteration: 260, Discriminator Loss: 1.300, Generator Loss: 0.664
# Iteration: 270, Discriminator Loss: 1.140, Generator Loss: 0.739
# Iteration: 280, Discriminator Loss: 1.296, Generator Loss: 0.626
# Iteration: 290, Discriminator Loss: 1.321, Generator Loss: 0.740
# Iteration: 300, Discriminator Loss: 1.200, Generator Loss: 0.678
# Iteration: 310, Discriminator Loss: 1.218, Generator Loss: 0.712
# Iteration: 320, Discriminator Loss: 1.200, Generator Loss: 0.723
# Iteration: 330, Discriminator Loss: 1.108, Generator Loss: 0.762
# Iteration: 340, Discriminator Loss: 1.109, Generator Loss: 0.746
# Iteration: 350, Discriminator Loss: 1.224, Generator Loss: 0.711
# Iteration: 360, Discriminator Loss: 1.137, Generator Loss: 0.784
# Iteration: 370, Discriminator Loss: 1.155, Generator Loss: 0.741
# Iteration: 380, Discriminator Loss: 1.376, Generator Loss: 0.688
# Iteration: 390, Discriminator Loss: 1.096, Generator Loss: 0.776
# Iteration: 400, Discriminator Loss: 1.186, Generator Loss: 0.787
# Iteration: 410, Discriminator Loss: 1.082, Generator Loss: 0.759
# Iteration: 420, Discriminator Loss: 1.261, Generator Loss: 0.691
# Iteration: 430, Discriminator Loss: 1.059, Generator Loss: 0.876
# Iteration: 440, Discriminator Loss: 1.268, Generator Loss: 0.699
# Iteration: 450, Discriminator Loss: 1.138, Generator Loss: 0.680
# Iteration: 460, Discriminator Loss: 1.268, Generator Loss: 0.666
# Iteration: 470, Discriminator Loss: 0.954, Generator Loss: 1.080
# Iteration: 480, Discriminator Loss: 0.908, Generator Loss: 0.982
# Iteration: 490, Discriminator Loss: 1.268, Generator Loss: 0.651
# Iteration: 500, Discriminator Loss: 1.219, Generator Loss: 0.725
# Iteration: 510, Discriminator Loss: 1.273, Generator Loss: 0.699
# Iteration: 520, Discriminator Loss: 0.993, Generator Loss: 0.906
# Iteration: 530, Discriminator Loss: 1.165, Generator Loss: 0.670
# Iteration: 540, Discriminator Loss: 1.213, Generator Loss: 0.736
# Iteration: 550, Discriminator Loss: 1.121, Generator Loss: 0.792
# Iteration: 560, Discriminator Loss: 1.000, Generator Loss: 1.127
# Iteration: 570, Discriminator Loss: 0.980, Generator Loss: 0.858
# Iteration: 580, Discriminator Loss: 1.055, Generator Loss: 0.760
# Iteration: 590, Discriminator Loss: 0.936, Generator Loss: 1.078
# Iteration: 600, Discriminator Loss: 0.974, Generator Loss: 0.814
# Iteration: 610, Discriminator Loss: 0.550, Generator Loss: 1.481
# Iteration: 620, Discriminator Loss: 0.788, Generator Loss: 1.051
# Iteration: 630, Discriminator Loss: 0.688, Generator Loss: 1.123
# Iteration: 640, Discriminator Loss: 0.806, Generator Loss: 0.969
# Iteration: 650, Discriminator Loss: 0.932, Generator Loss: 0.946
# Iteration: 660, Discriminator Loss: 0.458, Generator Loss: 1.629
# Iteration: 670, Discriminator Loss: 0.478, Generator Loss: 1.464
# Iteration: 680, Discriminator Loss: 0.619, Generator Loss: 1.301
# Iteration: 690, Discriminator Loss: 0.522, Generator Loss: 1.286
# Iteration: 700, Discriminator Loss: 0.671, Generator Loss: 1.111
# Iteration: 710, Discriminator Loss: 0.868, Generator Loss: 0.889
# Iteration: 720, Discriminator Loss: 0.508, Generator Loss: 1.240
# Iteration: 730, Discriminator Loss: 0.287, Generator Loss: 1.956
# Iteration: 740, Discriminator Loss: 0.453, Generator Loss: 1.703
# Iteration: 750, Discriminator Loss: 0.425, Generator Loss: 1.400
# Iteration: 760, Discriminator Loss: 0.382, Generator Loss: 1.560
# Iteration: 770, Discriminator Loss: 0.552, Generator Loss: 2.100
# Iteration: 780, Discriminator Loss: 0.324, Generator Loss: 1.937
# Iteration: 790, Discriminator Loss: 0.269, Generator Loss: 1.852
# Iteration: 800, Discriminator Loss: 0.253, Generator Loss: 2.460
# Iteration: 810, Discriminator Loss: 0.196, Generator Loss: 2.181
# Iteration: 820, Discriminator Loss: 0.155, Generator Loss: 2.380
# Iteration: 830, Discriminator Loss: 0.133, Generator Loss: 2.829
# Iteration: 840, Discriminator Loss: 0.265, Generator Loss: 1.743
# Iteration: 850, Discriminator Loss: 0.093, Generator Loss: 2.974
# Iteration: 860, Discriminator Loss: 0.198, Generator Loss: 2.275
# Iteration: 870, Discriminator Loss: 0.185, Generator Loss: 2.144
# Iteration: 880, Discriminator Loss: 0.073, Generator Loss: 3.308
# Iteration: 890, Discriminator Loss: 0.281, Generator Loss: 2.016
# Iteration: 900, Discriminator Loss: 0.254, Generator Loss: 2.032
# Iteration: 910, Discriminator Loss: 0.051, Generator Loss: 3.403
# Iteration: 920, Discriminator Loss: 0.081, Generator Loss: 3.229
# Iteration: 930, Discriminator Loss: 0.234, Generator Loss: 2.065
# Iteration: 940, Discriminator Loss: 0.232, Generator Loss: 2.324
# Iteration: 950, Discriminator Loss: 0.096, Generator Loss: 2.597
# Iteration: 960, Discriminator Loss: 0.062, Generator Loss: 3.674
# Iteration: 970, Discriminator Loss: 0.147, Generator Loss: 2.346
# Iteration: 980, Discriminator Loss: 0.138, Generator Loss: 2.855
# Iteration: 990, Discriminator Loss: 0.126, Generator Loss: 2.749
# Iteration: 1000, Discriminator Loss: 0.048, Generator Loss: 3.593
# Iteration: 1010, Discriminator Loss: 0.026, Generator Loss: 4.202
# Iteration: 1020, Discriminator Loss: 0.031, Generator Loss: 3.928
# Iteration: 1030, Discriminator Loss: 0.261, Generator Loss: 2.165
# Iteration: 1040, Discriminator Loss: 0.050, Generator Loss: 3.259
# Iteration: 1050, Discriminator Loss: 0.060, Generator Loss: 4.295
# Iteration: 1060, Discriminator Loss: 0.025, Generator Loss: 4.273
# Iteration: 1070, Discriminator Loss: 0.038, Generator Loss: 3.779
# Iteration: 1080, Discriminator Loss: 0.033, Generator Loss: 3.960
# Iteration: 1090, Discriminator Loss: 0.175, Generator Loss: 2.210
# Iteration: 1100, Discriminator Loss: 0.010, Generator Loss: 5.137
# Iteration: 1110, Discriminator Loss: 0.013, Generator Loss: 6.827
# Iteration: 1120, Discriminator Loss: 0.068, Generator Loss: 3.439
# Iteration: 1130, Discriminator Loss: 0.013, Generator Loss: 4.601
# Iteration: 1140, Discriminator Loss: 0.013, Generator Loss: 4.613
# Iteration: 1150, Discriminator Loss: 0.012, Generator Loss: 5.109
# Iteration: 1160, Discriminator Loss: 0.010, Generator Loss: 5.124
# Iteration: 1170, Discriminator Loss: 0.034, Generator Loss: 3.813
# Iteration: 1180, Discriminator Loss: 0.005, Generator Loss: 5.981
# Iteration: 1190, Discriminator Loss: 0.144, Generator Loss: 2.393
# Iteration: 1200, Discriminator Loss: 0.003, Generator Loss: 6.971
# Iteration: 1210, Discriminator Loss: 0.008, Generator Loss: 5.321
# Iteration: 1220, Discriminator Loss: 0.120, Generator Loss: 2.467
# Iteration: 1230, Discriminator Loss: 0.013, Generator Loss: 4.793
# Iteration: 1240, Discriminator Loss: 0.016, Generator Loss: 6.325
# Iteration: 1250, Discriminator Loss: 0.010, Generator Loss: 4.880
# Iteration: 1260, Discriminator Loss: 0.018, Generator Loss: 5.693
# Iteration: 1270, Discriminator Loss: 0.016, Generator Loss: 4.239
# Iteration: 1280, Discriminator Loss: 0.057, Generator Loss: 4.009
# Iteration: 1290, Discriminator Loss: 0.011, Generator Loss: 5.400
# Iteration: 1300, Discriminator Loss: 0.072, Generator Loss: 2.867
# Iteration: 1310, Discriminator Loss: 0.022, Generator Loss: 3.977
# Iteration: 1320, Discriminator Loss: 0.005, Generator Loss: 5.891
# Iteration: 1330, Discriminator Loss: 0.009, Generator Loss: 5.906
# Iteration: 1340, Discriminator Loss: 0.022, Generator Loss: 5.662
# Iteration: 1350, Discriminator Loss: 0.108, Generator Loss: 3.644
# Iteration: 1360, Discriminator Loss: 0.074, Generator Loss: 2.877
# Iteration: 1370, Discriminator Loss: 0.006, Generator Loss: 5.386
# Iteration: 1380, Discriminator Loss: 0.019, Generator Loss: 4.224
# Iteration: 1390, Discriminator Loss: 0.023, Generator Loss: 5.017
# Iteration: 1400, Discriminator Loss: 0.033, Generator Loss: 3.590
# Iteration: 1410, Discriminator Loss: 0.058, Generator Loss: 6.323
# Iteration: 1420, Discriminator Loss: 0.012, Generator Loss: 5.259
# Iteration: 1430, Discriminator Loss: 0.043, Generator Loss: 3.337
# Iteration: 1440, Discriminator Loss: 0.011, Generator Loss: 4.978
# Iteration: 1450, Discriminator Loss: 0.043, Generator Loss: 5.532
# Iteration: 1460, Discriminator Loss: 0.007, Generator Loss: 5.450
# Iteration: 1470, Discriminator Loss: 0.011, Generator Loss: 5.884
# Iteration: 1480, Discriminator Loss: 0.011, Generator Loss: 5.299
# Iteration: 1490, Discriminator Loss: 0.010, Generator Loss: 4.872
# Iteration: 1500, Discriminator Loss: 0.014, Generator Loss: 4.591
# Iteration: 1510, Discriminator Loss: 0.017, Generator Loss: 4.231
# Iteration: 1520, Discriminator Loss: 0.048, Generator Loss: 5.553
# Iteration: 1530, Discriminator Loss: 0.014, Generator Loss: 5.774
# Iteration: 1540, Discriminator Loss: 0.012, Generator Loss: 6.217
# Iteration: 1550, Discriminator Loss: 0.017, Generator Loss: 4.253
# Iteration: 1560, Discriminator Loss: 0.016, Generator Loss: 4.526
# Iteration: 1570, Discriminator Loss: 0.017, Generator Loss: 4.804
# Iteration: 1580, Discriminator Loss: 0.019, Generator Loss: 4.161
# Iteration: 1590, Discriminator Loss: 0.007, Generator Loss: 5.769
# Iteration: 1600, Discriminator Loss: 0.017, Generator Loss: 6.609
# Iteration: 1610, Discriminator Loss: 0.043, Generator Loss: 3.434
# Iteration: 1620, Discriminator Loss: 0.014, Generator Loss: 7.480
# Iteration: 1630, Discriminator Loss: 0.007, Generator Loss: 5.426
# Iteration: 1640, Discriminator Loss: 0.002, Generator Loss: 6.484
# Iteration: 1650, Discriminator Loss: 0.015, Generator Loss: 5.300
# Iteration: 1660, Discriminator Loss: 0.007, Generator Loss: 5.097
# Iteration: 1670, Discriminator Loss: 0.006, Generator Loss: 5.194
# Iteration: 1680, Discriminator Loss: 0.006, Generator Loss: 6.035
# Iteration: 1690, Discriminator Loss: 0.051, Generator Loss: 5.610
# Iteration: 1700, Discriminator Loss: 0.039, Generator Loss: 4.627
# Iteration: 1710, Discriminator Loss: 0.006, Generator Loss: 5.389
# Iteration: 1720, Discriminator Loss: 0.004, Generator Loss: 5.601
# Iteration: 1730, Discriminator Loss: 0.008, Generator Loss: 5.400
# Iteration: 1740, Discriminator Loss: 0.002, Generator Loss: 6.735
# Iteration: 1750, Discriminator Loss: 0.166, Generator Loss: 2.293
# Iteration: 1760, Discriminator Loss: 0.031, Generator Loss: 6.018
# Iteration: 1770, Discriminator Loss: 0.004, Generator Loss: 7.510
# Iteration: 1780, Discriminator Loss: 0.005, Generator Loss: 6.228
# Iteration: 1790, Discriminator Loss: 0.018, Generator Loss: 5.474
# Iteration: 1800, Discriminator Loss: 0.017, Generator Loss: 5.027
# Iteration: 1810, Discriminator Loss: 0.006, Generator Loss: 5.485
# Iteration: 1820, Discriminator Loss: 0.006, Generator Loss: 5.374
# Iteration: 1830, Discriminator Loss: 0.036, Generator Loss: 3.439
# Iteration: 1840, Discriminator Loss: 0.016, Generator Loss: 4.969
# Iteration: 1850, Discriminator Loss: 0.018, Generator Loss: 4.146
# Iteration: 1860, Discriminator Loss: 0.003, Generator Loss: 6.081
# Iteration: 1870, Discriminator Loss: 0.007, Generator Loss: 7.047
# Iteration: 1880, Discriminator Loss: 0.002, Generator Loss: 6.472
# Iteration: 1890, Discriminator Loss: 0.003, Generator Loss: 5.915
# Iteration: 1900, Discriminator Loss: 0.018, Generator Loss: 4.158
# Iteration: 1910, Discriminator Loss: 0.003, Generator Loss: 6.520
# Iteration: 1920, Discriminator Loss: 0.004, Generator Loss: 7.360
# Iteration: 1930, Discriminator Loss: 0.002, Generator Loss: 6.778
# Iteration: 1940, Discriminator Loss: 0.003, Generator Loss: 6.251
# Iteration: 1950, Discriminator Loss: 0.178, Generator Loss: 3.961
# Iteration: 1960, Discriminator Loss: 0.002, Generator Loss: 7.125
# Iteration: 1970, Discriminator Loss: 0.006, Generator Loss: 5.273
# Iteration: 1980, Discriminator Loss: 0.002, Generator Loss: 7.397
# Iteration: 1990, Discriminator Loss: 0.004, Generator Loss: 5.709
# Iteration: 2000, Discriminator Loss: 0.001, Generator Loss: 7.705

# %%
fig = plt.figure(figsize=(20, 10))
outer = gridspec.GridSpec(10, 4, wspace=0.2)

for i, images in enumerate(results):
    inner = gridspec.GridSpecFromSubplotSpec(1, images.size(0),
                    subplot_spec=outer[i])

    images = torch.squeeze(images, dim=1)
    for j, im in enumerate(images):

        ax = plt.Subplot(fig, inner[j])
        ax.imshow(im.numpy(), cmap="gray")
        ax.set_xticks([])
        ax.set_yticks([])
        if j==0:
            ax.set_title(f'Iteration {50+i*50}', loc='left')
        fig.add_subplot(ax)

plt.show()
