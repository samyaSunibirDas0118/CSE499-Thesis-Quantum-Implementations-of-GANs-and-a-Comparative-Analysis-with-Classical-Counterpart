# %% [markdown]
#  Question 5 : Samya Sunibir Das 1911563642

# %%
# !pip install qiskit
# !pip install pylatexenc
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from qiskit import *
from qiskit.tools.monitor import job_monitor
from qiskit.visualization import plot_state_qsphere
from qiskit.visualization import plot_histogram, plot_bloch_multivector, array_to_latex
import math

# %% [markdown]
# Uncertainty Principle
#
# 3 basis:
# 1. Z basis, standard - certain outcome
# 2. X basis, hadamard basis - random outcome
# 3. Y basis, circular basis

# %% [markdown]
# z basis - outcome is certain

# %%
# circuit creation
circuit = QuantumCircuit(1,1)


#measurement
circuit.measure(0, 0)

circuit.draw(output = 'mpl', initial_state=True)

# %%
#select simulator
simulator = Aer.get_backend('aer_simulator')

#assemble circuit
qobj = assemble(circuit)

#run on simulator
job = simulator.run(qobj)

#save statevector
circuit.save_statevector()

#monitor job
job_monitor(job)

#get result
result = job.result()

#get statevector
final_state = result.get_statevector()

#collect histogram data
count = result.get_counts()
# Out:
# Job Status: job has successfully run

# %%
print(final_state)
array_to_latex(final_state)
# Out:
# Statevector([1.+0.j, 0.+0.j],
#             dims=(2,))
# $$
#
# \begin{bmatrix}
# 1 & 0  \\
#  \end{bmatrix}
# $$

# %%
plot_bloch_multivector(final_state)

# %% [markdown]
# x basis - random outcome

# %%
# create circuit
circuit = QuantumCircuit(1, 1)

# apply gate
circuit.h(0)

# apply measurement --> X-basis measurement
circuit.measure(0, 0)

# draw circuit
circuit.draw(output = 'mpl', initial_state=True)

# %%
#select simulator
simulator = Aer.get_backend('aer_simulator')

#assemble circuit
q_obj = assemble(circuit)

#run on simulator
job = simulator.run(q_obj)

#save statevector
circuit.save_statevector()

#monitor job
job_monitor(job)

#get result
result = job.result()

#get statevector
final_state = result.get_statevector()

#collect histogram data
count = result.get_counts()
# Out:
# Job Status: job has successfully run

# %%
plot_bloch_multivector(final_state)

# %% [markdown]
# Y basis, Circular Basis

# %%
# create circuit
circuit = QuantumCircuit(1, 1)

# apply
circuit.sdg(0)
circuit.h(0)
circuit.measure(0, 0)

# draw circuit
circuit.draw(output = 'mpl', initial_state=True)

# %%
# Selecting a simulator
simulator = Aer.get_backend('aer_simulator')

# save statevector
circuit.save_statevector()

# assemble the circuit to a quantum object
quantum_obj = assemble(circuit)

# run on simulator
job = simulator.run(quantum_obj)
# using a job monitor for monitoring the process if the simulator run successfully
job_monitor(job)

# result from job
result = job.result()

# get statevector
final_state = result.get_statevector()
# collecting histogram data
counts = result.get_counts()
# Out:
# Job Status: job has successfully run

# %%
plot_bloch_multivector(final_state)

# %% [markdown]
# Measure for X,y,z where initialized in X

# %%
#basis for x
# create circuit
circuit = QuantumCircuit(1, 1)

# initialize x-basis
circuit.h(0)
# for different state
circuit.y(0)

# apply measurement 
circuit.h(0)
circuit.measure(0, 0)

# draw circuit
circuit.draw(output = 'mpl', initial_state=True)

# %%
#select simulator
simulator = Aer.get_backend('aer_simulator')

#assemble circuit
q_obj = assemble(circuit)

#run on simulator
job = simulator.run(q_obj)

#save statevector
circuit.save_statevector()

#monitor job
job_monitor(job)

#get result
result = job.result()

#get statevector
final_state = result.get_statevector()

#collect histogram data
count = result.get_counts()
# Out:
# Job Status: job has successfully run
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/qiskit/result/result.py in get_statevector(self, experiment, decimals)
#     313             return postprocess.format_statevector(
# --> 314                 self.data(experiment)["statevector"], decimals=decimals
#     315             )
#
# KeyError: 'statevector'
#
# The above exception was the direct cause of the following exception:
#
# QiskitError                               Traceback (most recent call last)
# <ipython-input-74-77a042c29fe7> in <module>()
#      18
#      19 #get statevector
# ---> 20 final_state = result.get_statevector()
#      21
#      22 #collect histogram data
#
# /usr/local/lib/python3.7/dist-packages/qiskit/result/result.py in get_statevector(self, experiment, decimals)
#     315             )
# ...

# %%
plot_bloch_multivector(final_state)

# %%
# basis for y
# create circuit
circuit = QuantumCircuit(1, 1)

# initialize x-basis
# apply 
circuit.h(0)
# for different state
circuit.y(0)

# apply measurement
circuit.sdg(0)
circuit.h(0)
circuit.measure(0, 0)

# draw circuit
circuit.draw(output = 'mpl', initial_state=True)

# %%
# Selecting a simulator
simulator = Aer.get_backend('aer_simulator')

# save statevector
circuit.save_statevector()

# assemble the circuit to a quantum object
quantum_obj = assemble(circuit)

# run on simulator
job = simulator.run(quantum_obj)
# using a job monitor for monitoring the process if the simulator run successfully
job_monitor(job)

# result from job
result = job.result()

# get statevector
final_state = result.get_statevector()
# collecting histogram data
counts = result.get_counts()
# Out:
# WARNING:qiskit.providers.aer.backends.aerbackend:Simulation failed and returned the following error message:
# ERROR: Failed to load qobj: Duplicate key "statevector" in save instruction.
# Job Status: job has successfully run
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# <ipython-input-75-4797789dc71c> in <module>()
#      17
#      18 # get statevector
# ---> 19 final_state = result.get_statevector()
#      20 # collecting histogram data
#      21 counts = result.get_counts()
#
# /usr/local/lib/python3.7/dist-packages/qiskit/result/result.py in get_statevector(self, experiment, decimals)
#     312         try:
#     313             return postprocess.format_statevector(
# --> 314                 self.data(experiment)["statevector"], decimals=decimals
#     315             )
#     316         except KeyError as ex:
#
# ...

# %%
plot_bloch_multivector(final_state)

# %%
#MEASUREMENT FOR Z BASIS
# create circuit
circuit = QuantumCircuit(1, 1)

# initialize x-basis
# apply
circuit.h(0)
# to take into |-> state
circuit.y(0)

# apply measurement --> Z-basis measurement
circuit.measure(0, 0)

# draw circuit
circuit.draw(output = 'mpl', initial_state=True)

# %%
# Selecting a simulator
simulator = Aer.get_backend('aer_simulator')

# save statevector
circuit.save_statevector()

# assemble the circuit to a quantum object
quantum_obj = assemble(circuit)

# run on simulator
job = simulator.run(quantum_obj)
# using a job monitor for monitoring the process if the simulator run successfully
job_monitor(job)

# result from job
result = job.result()

# get statevector
final_state = result.get_statevector()
# collecting histogram data
counts = result.get_counts()
# Out:
# Job Status: job has successfully run

# %%
plot_bloch_multivector(final_state)

# %%
#X basis
# create circuit
circuit = QuantumCircuit(1, 1)

# ybasis initialized
# apply 
circuit.sx(0)

# x measurement
circuit.h(0)
circuit.measure(0, 0)

# draw circuit
circuit.draw(output = 'mpl', initial_state=True)

# %%
# Selecting a simulator
simulator = Aer.get_backend('aer_simulator')

# save statevector
circuit.save_statevector()

# assemble the circuit to a quantum object
quantum_obj = assemble(circuit)

# run on simulator
job = simulator.run(quantum_obj)
# using a job monitor for monitoring the process if the simulator run successfully
job_monitor(job)

# result from job
result = job.result()

# get statevector
final_state = result.get_statevector()
# collecting histogram data
counts = result.get_counts()
# Out:
# Job Status: job has successfully run

# %%
plot_bloch_multivector(final_state)

# %% [markdown]
# measurement for y basis

# %%
# create circuit
circuit = QuantumCircuit(1, 1)

# xbasis intialize
# apply gate
circuit.sx(0)

# measurement for Ybasis
circuit.sdg(0)
circuit.h(0)
circuit.measure(0, 0)

# draw circuit
circuit.draw(output = 'mpl', initial_state=True)

# %%
# Selecting a simulator
simulator = Aer.get_backend('aer_simulator')

# save statevector
circuit.save_statevector()

# assemble the circuit to a quantum object
quantum_obj = assemble(circuit)

# run on simulator
job = simulator.run(quantum_obj)
# using a job monitor for monitoring the process if the simulator run successfully
job_monitor(job)

# result from job
result = job.result()

# get statevector
final_state = result.get_statevector()
# collecting histogram data
counts = result.get_counts()
# Out:
# Job Status: job has successfully run

# %%
plot_bloch_multivector(final_state)

# %%
# create circuit
circuit = QuantumCircuit(1, 1)

# initialize x-basis
# apply gate
circuit.sx(0)

#measurement for Zbasis
circuit.measure(0, 0)

# draw circuit
circuit.draw(output = 'mpl', initial_state=True)

# %%
# Selecting a simulator
simulator = Aer.get_backend('aer_simulator')

# save statevector
circuit.save_statevector()

# assemble the circuit to a quantum object
quantum_obj = assemble(circuit)

# run on simulator
job = simulator.run(quantum_obj)
# using a job monitor for monitoring the process if the simulator run successfully
job_monitor(job)

# result from job
result = job.result()

# get statevector
final_state = result.get_statevector()
# collecting histogram data
counts = result.get_counts()
# Out:
# Job Status: job has successfully run

# %%
plot_bloch_multivector(final_state)
